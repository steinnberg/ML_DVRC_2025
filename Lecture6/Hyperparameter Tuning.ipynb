# %%
! pip install optuna
# Out:
# Collecting optuna
#   Using cached optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from optuna) (1.15.2)
# Collecting colorlog (from optuna)
#   Using cached colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from alembic>=1.5.0->optuna) (1.3.9)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: colorama in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from colorlog->optuna) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\kered\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Using cached optuna-4.6.0-py3-none-any.whl (404 kB)
# Using cached colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
#
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    ---------------------------------------- 2/2 [optuna]
#
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
# ============================================================
# NOTEBOOK 2 — Hyperparameter Tuning
# Models : RandomForest, SVM
# Methods : GridSearchCV, RandomizedSearchCV, Optuna
# ============================================================

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.datasets import load_breast_cancer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

#import optuna
#from optuna.integration import SklearnPipelineSampler

import warnings
warnings.filterwarnings("ignore")

data = load_breast_cancer()
X = data.data
y = data.target

# %% [markdown]
# * 1. Baseline model

# %%
pipe_svm = Pipeline([
    ("scaler", StandardScaler()),
    ("model", SVC())
])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y)

pipe_svm.fit(X_train, y_train)
pipe_svm.score(X_test, y_test)
# Out:
# 0.9790209790209791

# %% [markdown]
# 2. GridSearchCV sur SVM

# %%
grid_params = {
    "model__C": [0.1, 1, 10],
    "model__gamma": ["scale", "auto"],
    "model__kernel": ["rbf", "linear"]
}

grid = GridSearchCV(pipe_svm, grid_params, cv=5, n_jobs=-1)
grid.fit(X_train, y_train)

print("Best parameters:", grid.best_params_)
print("Test accuracy:", grid.score(X_test, y_test))
# Out:
# Best parameters: {'model__C': 0.1, 'model__gamma': 'scale', 'model__kernel': 'linear'}
# Test accuracy: 0.986013986013986

# %% [markdown]
# 3. RandomizedSearchCV

# %%
# rand_params = {
#     "model__C": np.logspace(-3, 3, 20),
#     "model__gamma": np.logspace(-4, 1, 20),
#     "model__kernel": ["rbf"]
# }

rand_params = {
    "model__C": [0.1, 1, 10],
    "model__gamma": ["scale", "auto"],
    "model__kernel": ["rbf", "linear"]
}

rand = RandomizedSearchCV(
    pipe_svm, rand_params, n_iter=25, cv=5, n_jobs=-1, random_state=42)
rand.fit(X_train, y_train)

print("Best parameters:", rand.best_params_)
print("Test accuracy:", rand.score(X_test, y_test))
# Out:
# Best parameters: {'model__kernel': 'linear', 'model__gamma': 'scale', 'model__C': 0.1}
# Test accuracy: 0.986013986013986

# %% [markdown]
# 4. Tuning avec OPTUNA (optimisation bayésienne)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y)

# %%
import optuna
#from optuna.integration import SklearnPipelineSampler
def objective(trial):
    C = trial.suggest_loguniform("model__C", 1e-3, 1e3)
    gamma = trial.suggest_loguniform("model__gamma", 1e-4, 1)
    kernel = trial.suggest_categorical("model__kernel", ["rbf", "linear"])

    pipe = Pipeline([
        ("scaler", StandardScaler()),
        ("model", SVC(C=C, gamma=gamma, kernel=kernel))
    ])

    pipe.fit(X_train, y_train)
    return pipe.score(X_test, y_test)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

study.best_params
# Out:
# [I 2025-12-15 11:02:46,698] A new study created in memory with name: no-name-83ed8484-ea65-4c8c-a7c9-4d8fa576e059
# [I 2025-12-15 11:02:46,713] Trial 0 finished with value: 0.986013986013986 and parameters: {'model__C': 0.03531489347525025, 'model__gamma': 0.0013798717304495576, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:46,743] Trial 1 finished with value: 0.9790209790209791 and parameters: {'model__C': 5.897145071690378, 'model__gamma': 0.05477888511358748, 'model__kernel': 'rbf'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:46,819] Trial 2 finished with value: 0.6293706293706294 and parameters: {'model__C': 0.010769632213005384, 'model__gamma': 0.000992733282963463, 'model__kernel': 'rbf'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:46,863] Trial 3 finished with value: 0.6293706293706294 and parameters: {'model__C': 0.01815751651176672, 'model__gamma': 0.28691944846883755, 'model__kernel': 'rbf'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:46,886] Trial 4 finished with value: 0.972027972027972 and parameters: {'model__C': 4.700426770881975, 'model__gamma': 0.36191191252678817, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:46,949] Trial 5 finished with value: 0.8321678321678322 and parameters: {'model__C': 6.090453681154131, 'model__gamma': 0.5001036431143305, 'model__kernel': 'rbf'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,034] Trial 6 finished with value: 0.6293706293706294 and parameters: {'model__C': 0.001184060396324498, 'model__gamma': 0.02200083161312955, 'model__kernel': 'rbf'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,101] Trial 7 finished with value: 0.6293706293706294 and parameters: {'model__C': 0.0032791505383628758, 'model__gamma': 0.00946110343060894, 'model__kernel': 'rbf'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,148] Trial 8 finished with value: 0.958041958041958 and parameters: {'model__C': 911.0767400310062, 'model__gamma': 0.1854126800295553, 'model__kernel': 'rbf'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,175] Trial 9 finished with value: 0.958041958041958 and parameters: {'model__C': 4.650351106747095, 'model__gamma': 0.0017972327895506596, 'model__kernel': 'rbf'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,213] Trial 10 finished with value: 0.986013986013986 and parameters: {'model__C': 0.06295555715314013, 'model__gamma': 0.00015319167355539, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,238] Trial 11 finished with value: 0.986013986013986 and parameters: {'model__C': 0.0575600903705358, 'model__gamma': 0.00010200932879755745, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,302] Trial 12 finished with value: 0.986013986013986 and parameters: {'model__C': 0.08465012268475686, 'model__gamma': 0.00015520162366204987, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,351] Trial 13 finished with value: 0.986013986013986 and parameters: {'model__C': 0.23141852214169897, 'model__gamma': 0.0006103685590311064, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,403] Trial 14 finished with value: 0.986013986013986 and parameters: {'model__C': 0.40856533853846344, 'model__gamma': 0.004159352513567705, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,514] Trial 15 finished with value: 0.9370629370629371 and parameters: {'model__C': 117.81645056013696, 'model__gamma': 0.0003368686295877858, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,544] Trial 16 finished with value: 0.965034965034965 and parameters: {'model__C': 0.01566833017195083, 'model__gamma': 0.003480656024703063, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,584] Trial 17 finished with value: 0.986013986013986 and parameters: {'model__C': 1.033349515462326, 'model__gamma': 0.0003650893350779049, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,625] Trial 18 finished with value: 0.986013986013986 and parameters: {'model__C': 0.06895420390363925, 'model__gamma': 0.0014966570810175032, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,695] Trial 19 finished with value: 0.986013986013986 and parameters: {'model__C': 0.8405318953616585, 'model__gamma': 0.00022348448738742006, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,784] Trial 20 finished with value: 0.951048951048951 and parameters: {'model__C': 0.005361971559032386, 'model__gamma': 0.011915115467823428, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,842] Trial 21 finished with value: 0.986013986013986 and parameters: {'model__C': 0.058187880077193235, 'model__gamma': 0.00010535843343046435, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,872] Trial 22 finished with value: 0.986013986013986 and parameters: {'model__C': 0.04910240543108094, 'model__gamma': 0.0005077330220371041, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:47,936] Trial 23 finished with value: 0.986013986013986 and parameters: {'model__C': 0.13719054370292025, 'model__gamma': 0.00010538028450584618, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:48,015] Trial 24 finished with value: 0.9790209790209791 and parameters: {'model__C': 0.030234884707229674, 'model__gamma': 0.0007383967775722224, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:48,066] Trial 25 finished with value: 0.9440559440559441 and parameters: {'model__C': 0.002245280294519149, 'model__gamma': 0.00020894201027650398, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:48,164] Trial 26 finished with value: 0.986013986013986 and parameters: {'model__C': 0.452952184951027, 'model__gamma': 0.002482277597836927, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:48,196] Trial 27 finished with value: 0.951048951048951 and parameters: {'model__C': 0.008058665016601067, 'model__gamma': 0.000255843413264708, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:48,233] Trial 28 finished with value: 0.9790209790209791 and parameters: {'model__C': 1.2270358733765452, 'model__gamma': 0.006446060813996965, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# [I 2025-12-15 11:02:48,278] Trial 29 finished with value: 0.972027972027972 and parameters: {'model__C': 17.102218211519578, 'model__gamma': 0.04753417174987257, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.986013986013986.
# {'model__C': 0.03531489347525025,
#  'model__gamma': 0.0013798717304495576,
#  'model__kernel': 'linear'}

# %% [markdown]
# - On définit les hyperparams directement dans trial.suggest_*.

# %%
import optuna

def objective(trial):

    C = trial.suggest_float("C", 1e-3, 1e3, log=True)
    gamma = trial.suggest_float("gamma", 1e-4, 1, log=True)
    kernel = trial.suggest_categorical("kernel", ["rbf", "linear"])

    pipe = Pipeline([
        ("scaler", StandardScaler()),
        ("model", SVC(C=C, gamma=gamma, kernel=kernel))
    ])

    pipe.fit(X_train, y_train)
    return pipe.score(X_test, y_test)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

study.best_params
# Out:
# [I 2025-12-15 11:04:41,814] A new study created in memory with name: no-name-519847cd-a215-49bd-b8bc-b1e1a7d5ac3a
# [I 2025-12-15 11:04:41,834] Trial 0 finished with value: 0.951048951048951 and parameters: {'C': 20.975875477241228, 'gamma': 0.0001742278371154778, 'kernel': 'rbf'}. Best is trial 0 with value: 0.951048951048951.
# [I 2025-12-15 11:04:41,881] Trial 1 finished with value: 0.6293706293706294 and parameters: {'C': 0.05725471700702827, 'gamma': 0.3282448811251923, 'kernel': 'rbf'}. Best is trial 0 with value: 0.951048951048951.
# [I 2025-12-15 11:04:41,905] Trial 2 finished with value: 0.965034965034965 and parameters: {'C': 11.605122598354306, 'gamma': 0.6627669512529532, 'kernel': 'linear'}. Best is trial 2 with value: 0.965034965034965.
# [I 2025-12-15 11:04:42,020] Trial 3 finished with value: 0.9370629370629371 and parameters: {'C': 157.52445844330455, 'gamma': 0.0537758370345926, 'kernel': 'linear'}. Best is trial 2 with value: 0.965034965034965.
# [I 2025-12-15 11:04:42,041] Trial 4 finished with value: 0.986013986013986 and parameters: {'C': 1.066268444523783, 'gamma': 0.015021407851177043, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,074] Trial 5 finished with value: 0.9300699300699301 and parameters: {'C': 0.14919388541312678, 'gamma': 0.0022597916263280265, 'kernel': 'rbf'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,142] Trial 6 finished with value: 0.9440559440559441 and parameters: {'C': 243.8066250527739, 'gamma': 0.11742653969851939, 'kernel': 'rbf'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,168] Trial 7 finished with value: 0.986013986013986 and parameters: {'C': 0.142502494065934, 'gamma': 0.0012402618836701838, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,189] Trial 8 finished with value: 0.986013986013986 and parameters: {'C': 0.6163816843411835, 'gamma': 0.00011706713665375667, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,301] Trial 9 finished with value: 0.9370629370629371 and parameters: {'C': 205.0486607278664, 'gamma': 0.5918527014843963, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,330] Trial 10 finished with value: 0.9440559440559441 and parameters: {'C': 0.0012034843188947614, 'gamma': 0.011306413770936854, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,379] Trial 11 finished with value: 0.958041958041958 and parameters: {'C': 0.014298204348070869, 'gamma': 0.002685595632898048, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,432] Trial 12 finished with value: 0.986013986013986 and parameters: {'C': 3.292528150185772, 'gamma': 0.000848429661976588, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,483] Trial 13 finished with value: 0.986013986013986 and parameters: {'C': 0.5410066107432675, 'gamma': 0.01656542257278618, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,563] Trial 14 finished with value: 0.958041958041958 and parameters: {'C': 0.00843307819514671, 'gamma': 0.0007242019218674314, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,613] Trial 15 finished with value: 0.9790209790209791 and parameters: {'C': 4.044930251417039, 'gamma': 0.03516136491630444, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,698] Trial 16 finished with value: 0.986013986013986 and parameters: {'C': 0.16158875339376574, 'gamma': 0.0040958167399420915, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,746] Trial 17 finished with value: 0.9790209790209791 and parameters: {'C': 0.024468174352604465, 'gamma': 0.0005037495493014321, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,847] Trial 18 finished with value: 0.6293706293706294 and parameters: {'C': 0.002349034223016119, 'gamma': 0.00752735056084544, 'kernel': 'rbf'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:42,893] Trial 19 finished with value: 0.9790209790209791 and parameters: {'C': 2.5046565920195243, 'gamma': 0.02988570187444661, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,010] Trial 20 finished with value: 0.9370629370629371 and parameters: {'C': 972.3787231322036, 'gamma': 0.0014805467968438317, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,050] Trial 21 finished with value: 0.986013986013986 and parameters: {'C': 0.5677482487115681, 'gamma': 0.00016215122456122302, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,098] Trial 22 finished with value: 0.986013986013986 and parameters: {'C': 0.21362694717315328, 'gamma': 0.00010036504632619159, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,162] Trial 23 finished with value: 0.9790209790209791 and parameters: {'C': 1.1926871467344344, 'gamma': 0.0004937089666855109, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,203] Trial 24 finished with value: 0.965034965034965 and parameters: {'C': 12.438144029904628, 'gamma': 0.006116180018362408, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,359] Trial 25 finished with value: 0.986013986013986 and parameters: {'C': 0.05321109969540638, 'gamma': 0.000285052094357727, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,511] Trial 26 finished with value: 0.9440559440559441 and parameters: {'C': 0.48066548490596284, 'gamma': 0.0011697868958187169, 'kernel': 'rbf'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,584] Trial 27 finished with value: 0.986013986013986 and parameters: {'C': 0.059485502153078684, 'gamma': 0.10782036419592712, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,695] Trial 28 finished with value: 0.986013986013986 and parameters: {'C': 1.0740125196171837, 'gamma': 0.0003582409316953515, 'kernel': 'linear'}. Best is trial 4 with value: 0.986013986013986.
# [I 2025-12-15 11:04:43,812] Trial 29 finished with value: 0.951048951048951 and parameters: {'C': 19.252269165925732, 'gamma': 0.00017604133955036725, 'kernel': 'rbf'}. Best is trial 4 with value: 0.986013986013986.
# {'C': 1.066268444523783, 'gamma': 0.015021407851177043, 'kernel': 'linear'}

# %% [markdown]
# ### Questions : go further

# %% [markdown]
# 1️⃣ Tune a RandomForest :
#       - n_estimators
#       - max_depth
#       - min_samples_split
#
# 2️⃣ Compare the performances Grid vs Random vs Optuna.
#
# 3️⃣ Test Optuna with 200 trees.
#
# 4️⃣ Visualize the curve of convergence Optuna.

# %% [markdown]
# #### Test Optuna with 200 trees
