# %%
#! pip install optuna

# %%
# ============================================================
# NOTEBOOK 2 — Hyperparameter Tuning
# Models : RandomForest, SVM
# Methods : GridSearchCV, RandomizedSearchCV, Optuna
# ============================================================

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.datasets import load_breast_cancer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

import optuna
#from optuna.integration import SklearnPipelineSampler

import warnings
warnings.filterwarnings("ignore")

data = load_breast_cancer()
X = data.data
y = data.target

# %% [markdown]
# * 1. Baseline model

# %%
pipe_svm = Pipeline([
    ("scaler", StandardScaler()),
    ("model", SVC())
])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y)

pipe_svm.fit(X_train, y_train)
pipe_svm.score(X_test, y_test)
# Out:
# 0.9790209790209791

# %% [markdown]
# 2. GridSearchCV sur SVM

# %%
grid_params = {
    "model__C": [0.1, 1, 10],
    "model__gamma": ["scale", "auto"],
    "model__kernel": ["rbf", "linear"]
}

grid = GridSearchCV(pipe_svm, grid_params, cv=5, n_jobs=-1)
grid.fit(X_train, y_train)

print("Best parameters:", grid.best_params_)
print("Test accuracy:", grid.score(X_test, y_test))
# Out:
# Best parameters: {'model__C': 0.1, 'model__gamma': 'scale', 'model__kernel': 'linear'}
# Test accuracy: 0.986013986013986

# %% [markdown]
# 3. RandomizedSearchCV

# %%
rand_params = {
    "model__C": np.logspace(-3, 3, 20),
    "model__gamma": np.logspace(-4, 1, 20),
    "model__kernel": ["rbf"]
}

rand = RandomizedSearchCV(
    pipe_svm, rand_params, n_iter=25, cv=5, n_jobs=-1, random_state=42)
rand.fit(X_train, y_train)

rand.best_params_
# Out:
# {'model__kernel': 'rbf',
#  'model__gamma': 0.00379269019073225,
#  'model__C': 12.742749857031322}

# %% [markdown]
# 4. Tuning avec OPTUNA (optimisation bayésienne)

# %%
def objective(trial):
    C = trial.suggest_loguniform("model__C", 1e-3, 1e3)
    gamma = trial.suggest_loguniform("model__gamma", 1e-4, 1)
    kernel = trial.suggest_categorical("model__kernel", ["rbf", "linear"])

    pipe = Pipeline([
        ("scaler", StandardScaler()),
        ("model", SVC(C=C, gamma=gamma, kernel=kernel))
    ])

    pipe.fit(X_train, y_train)
    return pipe.score(X_test, y_test)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

study.best_params
# Out:
# [I 2025-11-20 11:03:19,571] A new study created in memory with name: no-name-36f1756f-4ee7-4d90-abfb-3e7e46df4a07
# [I 2025-11-20 11:03:19,590] Trial 0 finished with value: 0.951048951048951 and parameters: {'model__C': 0.006747264895006682, 'model__gamma': 0.022148572992812577, 'model__kernel': 'linear'}. Best is trial 0 with value: 0.951048951048951.
# [I 2025-11-20 11:03:19,603] Trial 1 finished with value: 0.986013986013986 and parameters: {'model__C': 232.5750683042674, 'model__gamma': 0.00019198483573759986, 'model__kernel': 'rbf'}. Best is trial 1 with value: 0.986013986013986.
# [I 2025-11-20 11:03:19,665] Trial 2 finished with value: 0.6293706293706294 and parameters: {'model__C': 0.004638787253429455, 'model__gamma': 0.009440103084689073, 'model__kernel': 'rbf'}. Best is trial 1 with value: 0.986013986013986.
# ...

# %% [markdown]
# - On définit les hyperparams directement dans trial.suggest_*.

# %%
import optuna

def objective(trial):

    C = trial.suggest_float("C", 1e-3, 1e3, log=True)
    gamma = trial.suggest_float("gamma", 1e-4, 1, log=True)
    kernel = trial.suggest_categorical("kernel", ["rbf", "linear"])

    pipe = Pipeline([
        ("scaler", StandardScaler()),
        ("model", SVC(C=C, gamma=gamma, kernel=kernel))
    ])

    pipe.fit(X_train, y_train)
    return pipe.score(X_test, y_test)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

study.best_params

# %% [markdown]
# ### Question : Allez plus loin

# %% [markdown]
# 1️⃣ Tuner un RandomForest :
#       - n_estimators
#       - max_depth
#       - min_samples_split
#
# 2️⃣ Comparer les performances Grid vs Random vs Optuna.
#
# 3️⃣ Tester Optuna avec 200 trees.
#
# 4️⃣ Visualiser la courbe de convergence Optuna.

# %% [markdown]
# ## 1. Tuner un RandomForest by Grid vs Random vs Optuna

# %%
# Tuner un RandomForest
import time
import numpy as np
import pandas as pd
from itertools import product
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

import optuna

# data split: train/val/test
data = load_breast_cancer()
X, y = data.data, data.target

X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full, test_size=0.25, random_state=42, stratify=y_train_full
)

# Encapsulate training and evaluation into a function
def fit_eval(params):
    clf = RandomForestClassifier(random_state=42, n_jobs=-1, **params)
    clf.fit(X_train, y_train)
    return clf.score(X_val, y_val), clf.score(X_test, y_test)

# Baseline
base_val, base_test = fit_eval({})

# Grid 
grid_space = {
    "n_estimators":[100, 200],
    "max_depth":[None, 5, 10],
    "min_samples_split":[2, 5],
}
best_grid = None
grid_best_so_far = []
grid_records = []

cur_best = -1
for i, (n, d, m) in enumerate(product(grid_space["n_estimators"],
                                      grid_space["max_depth"],
                                      grid_space["min_samples_split"]), start=1):
    p = {"n_estimators": n, "max_depth": d, "min_samples_split": m}
    va, te = fit_eval(p)

    grid_records.append({"method":"Grid", "iter": i, **p, "val": va, "test": te})

    if best_grid is None or va > best_grid["val"]:
        best_grid = {"params": p, "val": va, "test": te}

    cur_best = max(cur_best, va)
    grid_best_so_far.append(cur_best)

# Random 
rng = np.random.default_rng(42)
def sample_params():
    return {
        "n_estimators": int(rng.integers(50, 301)),
        "max_depth": None if rng.random() < 0.25 else int(rng.integers(2, 21)),
        "min_samples_split": int(rng.integers(2, 21)),
    }

best_rand = None
rand_best_so_far = []
rand_records = []

cur_best = -1
for i in range(1, 21):  # 你原来是 20 次
    p = sample_params()
    va, te = fit_eval(p)

    rand_records.append({"method":"Random", "iter": i, **p, "val": va, "test": te})

    if best_rand is None or va > best_rand["val"]:
        best_rand = {"params": p, "val": va, "test": te}

    cur_best = max(cur_best, va)
    rand_best_so_far.append(cur_best)

# Optuna
def objective(trial):
    p = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 250),
        "max_depth": trial.suggest_categorical("max_depth", [None] + list(range(2, 21))),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
    }
    va, _ = fit_eval(p)
    return va

sampler = optuna.samplers.TPESampler(seed=13)
study = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=25)

opt_params = study.best_params
opt_val, opt_test = fit_eval(opt_params)

opt_best_so_far = []
cur_best = -1
for t in study.trials:
    if t.value is None:
        continue
    cur_best = max(cur_best, t.value)
    opt_best_so_far.append(cur_best)
# Out:
# [I 2025-12-15 04:22:36,419] A new study created in memory with name: no-name-22577293-c313-4daa-87d9-7a91cc51346f
# [I 2025-12-15 04:22:36,698] Trial 0 finished with value: 0.9439252336448598 and parameters: {'n_estimators': 206, 'max_depth': 4, 'min_samples_split': 6}. Best is trial 0 with value: 0.9439252336448598.
# [I 2025-12-15 04:22:36,856] Trial 1 finished with value: 0.9626168224299065 and parameters: {'n_estimators': 114, 'max_depth': 13, 'min_samples_split': 6}. Best is trial 1 with value: 0.9626168224299065.
# [I 2025-12-15 04:22:37,058] Trial 2 finished with value: 0.9439252336448598 and parameters: {'n_estimators': 142, 'max_depth': 12, 'min_samples_split': 5}. Best is trial 1 with value: 0.9626168224299065.
# [I 2025-12-15 04:22:37,267] Trial 3 finished with value: 0.9439252336448598 and parameters: {'n_estimators': 148, 'max_depth': 2, 'min_samples_split': 8}. Best is trial 1 with value: 0.9626168224299065.
# ...

# %% [markdown]
# ## 2. Comparer les performances Grid vs Random vs Optuna

# %%
# ------------------------------------
# Comparison table
# ------------------------------------
summary = pd.DataFrame([
    {"Method":"Baseline", "Trials":1,  "Best Val": base_val, "Test": base_test, "Best Params": {}},
    {"Method":"Grid",     "Trials":len(grid_records), "Best Val": best_grid["val"], "Test": best_grid["test"], "Best Params": best_grid["params"]},
    {"Method":"Random",   "Trials":len(rand_records), "Best Val": best_rand["val"], "Test": best_rand["test"], "Best Params": best_rand["params"]},
    {"Method":"Optuna",   "Trials":len(opt_best_so_far), "Best Val": opt_val, "Test": opt_test, "Best Params": opt_params},
]).sort_values("Best Val", ascending=False)

print(summary.to_string(index=False))

# ------------------------------------
# 6) Comparison Bar Chart（Best Val vs Test）
# ------------------------------------
x = np.arange(len(summary))
plt.figure()
plt.bar(x - 0.2, summary["Best Val"].to_numpy(), width=0.4, label="Best Val")
plt.bar(x + 0.2, summary["Test"].to_numpy(), width=0.4, label="Test")
plt.xticks(x, summary["Method"].tolist(), rotation=15)
plt.ylabel("Accuracy")
plt.title("Grid vs Random vs Optuna (Best Val & Test)")
plt.legend()
plt.tight_layout()
plt.show()

# ------------------------------------
# Convergence curve（best-so-far）
# ------------------------------------
plt.figure()
plt.plot(grid_best_so_far, label="Grid best-so-far")
plt.plot(rand_best_so_far, label="Random best-so-far")
plt.plot(opt_best_so_far,  label="Optuna best-so-far")
plt.xlabel("Iteration / Trial")
plt.ylabel("Best validation accuracy so far")
plt.title("Convergence comparison")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#   Method  Trials  Best Val     Test                                                      Best Params
#     Grid      12  0.962617 0.951049 {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 5}
#   Random      20  0.962617 0.951049   {'n_estimators': 72, 'max_depth': 16, 'min_samples_split': 10}
#   Optuna      25  0.962617 0.951049   {'n_estimators': 114, 'max_depth': 13, 'min_samples_split': 6}
# Baseline       1  0.953271 0.951049                                                               {}

# %% [markdown]
# ### Grid vs Random vs Optuna
#
# #### Final results
# - All three methods reached the same best validation accuracy: **Best Val Acc = 0.9626**
# - On the test set, they ended up with essentially the same performance: **Test Acc = 0.9510**
#
# This suggests that tuning improved validation performance up to **0.9626**, but it did"t translate into a noticeable generalization gain on the test set (still **0.9510**).
#
# ---
#
# #### Analysis according to convergence curves (best-so-far)
# From the convergence plot, the three best-so-far curves reach the maximum level (≈ **0.9626**) within the first 1–2 trials and then stay flat. That means the optimum is found very quickly, and additional trials bring little to no improvement.
#
# - **Random**: it hits **0.9626** almost immediately, which indicates the random sampling got a very good configuration early.
# - **Grid**: it also reaches **0.9626** quickly because the grid is small, so exhaustive enumeration covers strong candidates early.
# - **Optuna**: it starts a bit lower but catches up to **0.9626** very fast and then plateaus. It shows that in this relatively small search space, Optuna’s smart search advantage is not very visible.
#
# **Overall conclusion:** Grid, Random, and Optuna achieve the same best validation score (**0.9626**) and the same test score (**0.9510**). The main difference here is **how fast** they reach the best validation score, not the final performance.

# %%
# ------------------------------------
# Runtime benchmark
# ------------------------------------
best_list = [
    ("Grid",   {'n_estimators': 100, 'max_depth': None, 'min_samples_split': 5}),
    ("Random", {'n_estimators': 72,  'max_depth': 16,   'min_samples_split': 10}),
    ("Optuna", {'n_estimators': 96,  'max_depth': 16,   'min_samples_split': 4}),
]

for name, p in best_list:
    clf = RandomForestClassifier(random_state=42, n_jobs=-1, **p)

    t0 = time.perf_counter()
    clf.fit(X_train, y_train)
    fit_t = time.perf_counter() - t0

    t0 = time.perf_counter()
    _ = clf.predict(X_test)
    pred_t = time.perf_counter() - t0

    print(name, "fit(s)=", round(fit_t, 4), "pred(s)=", round(pred_t, 4), "test_acc=", clf.score(X_test, y_test))
# Out:
# Grid fit(s)= 0.1406 pred(s)= 0.0221 test_acc= 0.951048951048951
# Random fit(s)= 0.0841 pred(s)= 0.016 test_acc= 0.951048951048951
# Optuna fit(s)= 0.1134 pred(s)= 0.0164 test_acc= 0.951048951048951

# %% [markdown]
# ### Hyperparameter from Grid vs Random vs Optuna
#
# #### Runtime note
# Even if Grid/Random/Optuna reach the same **Best Val Acc = 0.9626** and **Test Acc = 0.9510**, they selected different hyperparameters. This may affects a lot **runtime efficiency** on larger datasets,so runtime becomes the differentiator.
#
# Measured on the same train/test split:
#
# - **Grid**: fit **0.1406s**, predict **0.0221s**
# - **Random**: fit **0.0841s**, predict **0.0016s**
# - **Optuna**: fit **0.1134s**, predict **0.0164s**
#
# **Random** is the fastest overall (both training and prediction), while **Optuna** comes in second. **Grid** is the slowest, especially at prediction time.

# %% [markdown]
# ## 3. Tester Optuna avec 200 trees.

# %%
def objective_200(trial):
    p = {
        "n_estimators": 200,
        "max_depth": trial.suggest_categorical("max_depth", [None] + list(range(2, 21))),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
    }
    va, _ = fit_eval(p)
    return va

study200 = optuna.create_study(direction="maximize")
study200.optimize(objective_200, n_trials=25)

best200 = study200.best_params
val200, test200 = fit_eval({"n_estimators": 200, **best200})
# Out:
# [I 2025-12-15 04:27:51,957] A new study created in memory with name: no-name-38cb684d-cd28-45be-a043-f8b7d465f7a5
# [I 2025-12-15 04:27:52,259] Trial 0 finished with value: 0.9439252336448598 and parameters: {'max_depth': 15, 'min_samples_split': 8}. Best is trial 0 with value: 0.9439252336448598.
# [I 2025-12-15 04:27:52,532] Trial 1 finished with value: 0.9532710280373832 and parameters: {'max_depth': 14, 'min_samples_split': 4}. Best is trial 1 with value: 0.9532710280373832.
# [I 2025-12-15 04:27:52,805] Trial 2 finished with value: 0.9345794392523364 and parameters: {'max_depth': 11, 'min_samples_split': 18}. Best is trial 1 with value: 0.9532710280373832.
# [I 2025-12-15 04:27:53,075] Trial 3 finished with value: 0.9252336448598131 and parameters: {'max_depth': 19, 'min_samples_split': 20}. Best is trial 1 with value: 0.9532710280373832.
# ...

# %% [markdown]
# ## 4. Visualiser la courbe de convergence Optuna

# %%
best_so_far_200_Optuna = []
cur = -1
for t in study200.trials:
    if t.value is None:
        continue
    cur = max(cur, t.value)
    best_so_far_200_Optuna.append(cur)

plt.plot(best_so_far_200_Optuna)
plt.xlabel("Trial")
plt.ylabel("Best validation accuracy so far with Optuna_200_trees")
plt.title("Optuna_200_trees convergence")
plt.show()
